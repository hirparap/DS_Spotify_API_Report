# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import pandas as pd
import time

cid = "ca030d66c87b4af0b2db85526c441c9b"
secret = "6833176090ef4bb6858f564b82fe2d85" 

spotify = spotipy.Spotify(client_credentials_manager=SpotifyClientCredentials(client_id=cid, client_secret=secret))

# %%
def get_pd_entry(s_id):
    track = spotify.track("spotify:track:" + s_id)
    a_fts = spotify.audio_features("spotify:track:" + s_id)[0]
    
    # Track Features
    song_name = track.get("name")
    artist_name = track.get("artists")[0].get("name")
    popularity = track.get("popularity")
    
    # Audio Features
    acousticness = a_fts.get("acousticness")
    danceability = a_fts.get("danceability")
    speechiness = a_fts.get("speechiness")
    energy = a_fts.get("energy")
    liveness = a_fts.get("liveness")
    valence = a_fts.get("valence")
    
    dict_entry = {"Name" : song_name,
                  "Artist" : artist_name,
                  "Popularity" : popularity,
                  "Acousticness" : acousticness,
                  "Danceability" : danceability,
                  "Speechiness" : speechiness,
                  "Energy" : energy,
                  "Liveness" : liveness,
                  "Valence" : valence}
    
    return dict_entry

# %%
dataframe = pd.read_csv("positive_samples_names.csv")

# %%
output = pd.DataFrame()
for i in range(1000):
    curr_song = dataframe.iat[i, 1]
    sid = spotify.search(curr_song, limit = 1, type = "track", market = "US").get("tracks").get("items")[0].get("id")
    pd_entry = get_pd_entry(sid)
    output = output.append(pd_entry, ignore_index=True)
    time.sleep(0.1)

    
output.to_csv("positive_samples.csv")    
output
# Out:
# retrying ...1secs
# retrying ...1secs
# retrying ...1secs
# retrying ...1secs
# retrying ...1secs
# retrying ...1secs
# retrying ...1secs
# retrying ...1secs
# retrying ...1secs
# retrying ...1secs
# retrying ...1secs
#      Acousticness         Artist  Danceability  Energy  Liveness  \
# 0         0.16400   Mariah Carey         0.335   0.625    0.0708
# 1         0.64300    Bobby Helms         0.754   0.424    0.0652
# 2         0.61400     Brenda Lee         0.589   0.472    0.5050
# 3         0.57900      Burl Ives         0.683   0.375    0.0760
# 4         0.92000  Nat King Cole         0.319   0.210    0.1380
# ..            ...            ...           ...     ...       ...
# 995       0.08020  Black Sabbath         0.318   0.650    0.0962
# 996       0.47400     Ed Sheeran         0.781   0.445    0.1840
# 997       0.08620     Tory Lanez         0.546   0.529    0.1240
# 998       0.01830      Elle King         0.612   0.921    0.0576
# 999       0.00188    Demi Lovato         0.594   0.749    0.0869
#
#                                             Name  Popularity  Speechiness  \
# 0                All I Want for Christmas Is You        72.0       0.0386
# 1                               Jingle Bell Rock        63.0       0.0363
# 2              Rockin' Around The Christmas Tree        64.0       0.0502
# 3       A Holly Jolly Christmas - Single Version        54.0       0.0303
# 4    The Christmas Song (Merry Christmas To You)        60.0       0.0341
# ..                                           ...         ...          ...
# 995        Children of the Grave - 2014 Remaster        57.0       0.0375
# 996                            Thinking out Loud        82.0       0.0295
# 997                                       Say It        71.0       0.0583
# 998                                  Ex's & Oh's        71.0       0.0848
# 999                                    Confident        74.0       0.0677
#
#      Valence
# 0      0.346
# 1      0.806
# 2      0.898
# 3      0.888
# 4      0.209
# ..       ...
# 995    0.368
# 996    0.591
# 997    0.247
# 998    0.453
# 999    0.344
#
# [1000 rows x 9 columns]
